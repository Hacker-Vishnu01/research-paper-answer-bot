# %% [markdown]
# # Research Paper Answer Bot - Capstone Experiments
#
# This notebook contains exploratory analysis, chunking parameter evaluations, embedding comparisons, and retrieval experiments.

# %%
# Environment Setup
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.insert(0, os.path.abspath('..'))

from src.config import config
print('Configuration initialized. Base dir:', config.base_dir)
